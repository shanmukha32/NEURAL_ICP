# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.3306 - loss: 15.3912
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.4355 - loss: 5.9912
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.5831 - loss: 2.8373
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.5033 - loss: 2.1655
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5022 - loss: 1.7500
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.5351 - loss: 1.2685
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5923 - loss: 1.0932
# Epoch 8/100
# ...

# %% [markdown]
# The accuracy was 0.72 for the given code you have provided
#
# we have added more dense layers to the given the code and you can see the results below

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# Load dataset
dataset = pd.read_csv("diabetes.csv", header=None).values
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)

# Define the model
np.random.seed(155)
my_first_nn = Sequential()
my_first_nn.add(Dense(20, input_dim=8, activation='relu'))  # Hidden layer 1
my_first_nn.add(Dense(15, activation='relu'))                # Hidden layer 2
my_first_nn.add(Dense(10, activation='relu'))                # Hidden layer 3
my_first_nn.add(Dense(1, activation='sigmoid'))              # Output layer

# Compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Evaluate the model
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - acc: 0.5848 - loss: 1.6046
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5451 - loss: 1.1325
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.6037 - loss: 0.8678
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6337 - loss: 0.8350
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6293 - loss: 0.8483
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6371 - loss: 0.7645
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.6309 - loss: 0.7559
# Epoch 8/100
# ...

# %% [markdown]
# The accuarcy was changed from 0.72 to 0.74 after adding some more dense layers to the code

# %% [markdown]
# In the below code i have chaged the dataset from diabetes to breast cancer and i already normalised the data using the StandardScaler

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# Load dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Split dataset
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)

# Normalize the data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Define the model
np.random.seed(155)
my_first_nn = Sequential()
my_first_nn.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))  # Hidden layer 1
my_first_nn.add(Dense(15, activation='relu'))                               # Hidden layer 2
my_first_nn.add(Dense(10, activation='relu'))                               # Hidden layer 3
my_first_nn.add(Dense(1, activation='sigmoid'))                             # Output layer

# Compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Evaluate the model
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - acc: 0.5713 - loss: 0.7579
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6373 - loss: 0.5924
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.6111 - loss: 0.5199
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.6386 - loss: 0.4582
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.7248 - loss: 0.4031
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.8600 - loss: 0.3474
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9365 - loss: 0.2934
# Epoch 8/100
# ...

# %% [markdown]
# The above summary is after updating the dataset to breastcancer

# %% [markdown]
# "IMAGE CLASSIFICATION"

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (28, 28)
# 784
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 15s 57ms/step - accuracy: 0.8310 - loss: 0.5439 - val_accuracy: 0.9568 - val_loss: 0.1407
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9658 - loss: 0.1125 - val_accuracy: 0.9633 - val_loss: 0.1173
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.9805 - loss: 0.0634 - val_accuracy: 0.9776 - val_loss: 0.0691
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9866 - loss: 0.0440 - val_accuracy: 0.9780 - val_loss: 0.0760
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9898 - loss: 0.0307 - val_accuracy: 0.9778 - val_loss: 0.0775
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9932 - loss: 0.0227 - val_accuracy: 0.9792 - val_loss: 0.0692
# Epoch 7/10
# ...

# %% [markdown]
# "PLOT OF LOSS AND ACCURACY"

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %% [markdown]
# "PLOT AN IMAGE AND MAKE PREDICTION"

# %%
# Plot one image from the test set
plt.imshow(test_images[0], cmap='gray')
plt.title('Test Image')
plt.show()

# Prepare the image for prediction
test_image = test_data[0].reshape(1, 784)  # Reshape to match model input

# Make a prediction
prediction = model.predict(test_image)
predicted_class = np.argmax(prediction)

print(f'Predicted class: {predicted_class}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Predicted class: 7

# %% [markdown]
# "CHANGE HIDDEN LAYERS AND ACTIVATION FUNCTION"

# %% [markdown]
# I have changed the number of neurons to 256 and activation function to tanh for hidden layers

# %%
model = Sequential()
model.add(Dense(256, activation='tanh', input_shape=(dimData,)))
model.add(Dense(256, activation='tanh'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1, validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8322 - loss: 0.5412 - val_accuracy: 0.9316 - val_loss: 0.2355
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9416 - loss: 0.1942 - val_accuracy: 0.9406 - val_loss: 0.1855
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9621 - loss: 0.1298 - val_accuracy: 0.9615 - val_loss: 0.1258
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9713 - loss: 0.0975 - val_accuracy: 0.9612 - val_loss: 0.1273
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9768 - loss: 0.0755 - val_accuracy: 0.9698 - val_loss: 0.0954
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9828 - loss: 0.0565 - val_accuracy: 0.9768 - val_loss: 0.0745
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9866 - loss: 0.0456 - val_accuracy: 0.9763 - val_loss: 0.0743
# Epoch 8/10
# ...

# %% [markdown]
# "RUN CODE WITHOUT SCALING IMAGES"

# %% [markdown]
# If we try to run the code without normalizing the pixel values we can see the perfomace has decreased due to the unscaled input data

# %%
train_data = train_images.reshape(train_images.shape[0], dimData)
test_data = test_images.reshape(test_images.shape[0], dimData)

# No normalization
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1, validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 29ms/step - accuracy: 0.7745 - loss: 25.9791 - val_accuracy: 0.9038 - val_loss: 1.0575
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9434 - loss: 0.4782 - val_accuracy: 0.9291 - val_loss: 0.6042
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9599 - loss: 0.2563 - val_accuracy: 0.9530 - val_loss: 0.3366
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9689 - loss: 0.1739 - val_accuracy: 0.9566 - val_loss: 0.3120
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9726 - loss: 0.1559 - val_accuracy: 0.9581 - val_loss: 0.3356
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9781 - loss: 0.1271 - val_accuracy: 0.9600 - val_loss: 0.3490
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9789 - loss: 0.1263 - val_accuracy: 0.9650 - val_loss: 0.3258
# Epoch 8/10
# ...

# %% [markdown]
# this code has took execution time of 1 min where as if the images are scaled it took only 32 sec as it shows half of the performance has dropped due to not scaling the images
